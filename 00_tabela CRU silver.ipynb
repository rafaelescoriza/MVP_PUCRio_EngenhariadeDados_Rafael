-- %%
-- SELECT ID, Idade , Genero , Senioridade_Facul ,Curso,Presenca,hrs_estudo_semanal, media_acumulada,desempenho_academico, habil_programacao,projetos_concluidos,certificacoes,  hackathons, perfil_github,estagios, exp_lideranca, perfil_linkedin,curriculo_pontuacao,habil_comunicacao, trabalho_em_equipe, resolucao_problemas, proficiencia_ingles,pontuacao_entrevista,  pontuacao_emprego,situacao_emprego,nivel_empresa, area_carreira,modo_emprego, salario_inicial
