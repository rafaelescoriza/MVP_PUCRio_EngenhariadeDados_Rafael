-- %%
USE CATALOG catalogo_mvp_engenhariadedados;
USE SCHEMA schema_mvp_engenhariadedados;
CREATE OR REPLACE TABLE tabela_estudantes_bronze_v00
AS
SELECT *
FROM read_files(
  '/Volumes/catalogo_mvp_engenhariadedados/schema_mvp_engenhariadedados/volume_mpv_engenhariadedados/student_career_success_dataset.csv',
  format => 'csv',
  header => true,
  sep => ','
);

-- %%
SELECT *
FROM tabela_estudantes_bronze_v00
