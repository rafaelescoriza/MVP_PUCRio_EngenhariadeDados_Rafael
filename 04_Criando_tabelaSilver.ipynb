-- %%
USE CATALOG catalogo_mvp_engenhariadedados;
USE SCHEMA schema_mvp_engenhariadedados;

CREATE OR REPLACE TABLE tabela_estudantes_silver_v00 AS
SELECT Student_ID as ID, Age as Idade , Gender as Genero , University_Year as Senioridade_Facul , Major as Curso, Attendance_Percentage as Presenca,Study_Hours_Per_Week as hrs_estudo_semanal, CGPA as media_acumulada,Academic_Performance as desempenho_academico, Programming_Skill as habil_programacao, Projects_Completed as projetos_concluidos,Certifications as certificacoes, Hackathons as hackathons, GitHub_Profile as perfil_github, Internships as estagios, Leadership_Experience as exp_lideranca, LinkedIn_Profile as perfil_linkedin,Resume_Score as curriculo_pontuacao,Communication_Skills as habil_comunicacao, Teamwork as trabalho_em_equipe, problem_solving as resolucao_problemas, English_proficiency as proficiencia_ingles,Interview_Score as pontuacao_entrevista, Employability_Score as pontuacao_emprego,Placement_Status as situacao_emprego,Company_tier as nivel_empresa, Career_field as area_carreira,Placement_mode as modo_emprego, Starting_Salary_USD as salario_inicial
FROM tabela_estudantes_bronze_v00;
