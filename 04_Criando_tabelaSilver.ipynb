-- %%
USE CATALOG catalogo_mvp_engenhariadedados;
USE SCHEMA schema_mvp_engenhariadedados;


CREATE OR REPLACE TABLE tabela_estudantes_silver_v00
SELECT Student_ID as ID, Age as Idade , Gender as Genero , University_Year as Senioridade_Facul , Major as Curso, Attendance_Percentage as Presenca,Study_Hours_Per_Week as hrs_estudo_semanal, CGPA as media_acumulada, Programming_Skill as habil_programacao, Projects_Completed as projetos_concluidos,Certifications as certificacoes, Hackathons as hackathons, GitHub_Profile as perfil_github, Internships as estagios, Leadership_Experience as exp_lideranca,Academic_Performance as desempenho_academico, LinkedIn_Profile as perfil_linkedin,Employability_Score as pontuacao_emprego, Resume_Score as pontuacao_curriculo, Communication_Skills as habil_comunicacao, Starting_Salary_USD as salario_inicial
FROM tabela_estudantes_bronze_v00
WHERE Starting_Salary_USD > 0
